# %% [markdown]
# # 01 Data Loading

# %%
#loading Data into DataFrame
import pandas as pd
df=pd.read_excel("C:/Users/Siddhesh/Downloads/Projects/E-commerce/ecommerce-sales-customer-intelligence/data/raw/Ecommerce_Retail_20K.xlsx")
print(df.shape)
# Out:
# (20000, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    20000 non-null  object
#  1   StockCode    20000 non-null  object
#  2   Description  19937 non-null  str
#  3   Quantity     20000 non-null  int64
#  4   InvoiceDate  20000 non-null  datetime64[us]
#  5   UnitPrice    20000 non-null  float64
#  6   CustomerID   15065 non-null  float64
#  7   Country      20000 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), object(2), str(2)
# memory usage: 1.2+ MB

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    555150     22762        CUPBOARD 3 DRAWER MA CAMPAGNE         1
# 1    575477     22645  CERAMIC HEART FAIRY CAKE MONEY BANK         1
# 2    538177    84596E         SMALL LICORICE DES PINK BOWL         1
# 3    575930     23378    PACK OF 12 50'S CHRISTMAS TISSUES         1
# 4    546890     22084               PAPER CHAIN KIT EMPIRE         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2011-05-31 15:53:00      29.17         NaN  United Kingdom
# 1 2011-11-09 16:14:00       3.29         NaN  United Kingdom
# 2 2010-12-10 09:51:00       2.51         NaN  United Kingdom
# 3 2011-11-11 17:58:00       0.83         NaN  United Kingdom
# 4 2011-03-17 18:18:00       2.95     13394.0  United Kingdom

# %%
# Out:
# (20000, 8)
